# %%
import pandas as pd
import numpy as np

# %%
#reading the excel file
df_video_raw = pd.read_excel('C:\\Users\\user\\Desktop\\Labeled_videos_data\\Labeled_video_42136_RF_W01.xlsx')
df_video_raw
# Out:
#          Column1                                         Column2  \
# 0         scorer  DLC_resnet50_Dystonia_TestApr21shuffle1_500000
# 1      bodyparts                                            nose
# 2         coords                                               x
# 3              0                              156.81517028808594
# 4              1                              157.75209045410156
# ...          ...                                             ...
# 18862      18859                              277.65142822265625
# 18863      18860                               272.4924011230469
# 18864      18861                              264.37518310546875
# 18865      18862                                   259.603515625
# 18866      18863                              253.30963134765625
#
#                                               Column3  \
# 0      DLC_resnet50_Dystonia_TestApr21shuffle1_500000
# 1                                                nose
# ...

# %%
# remove first row
df_video_raw = df_video_raw.drop(index=0)

# %%
# remove second column
df_video_raw = df_video_raw.drop(columns='Column1')

# %%
#showing the dataframe
df_video_raw
# Out:
#                   Column2             Column3             Column4  \
# 1                    nose                nose                nose
# 2                       x                   y          likelihood
# 3      156.81517028808594  227.42062377929688  0.9999908208847046
# 4      157.75209045410156  233.62486267089844  0.9999220371246338
# 5       158.3218994140625   238.5648651123047  0.9999498128890991
# ...                   ...                 ...                 ...
# 18862  277.65142822265625   601.4768676757812  0.9998972415924072
# 18863   272.4924011230469   601.4768676757812  0.9996892213821411
# 18864  264.37518310546875       601.912109375  0.9981042146682739
# 18865       259.603515625   601.4768676757812  0.9998396635055542
# 18866  253.30963134765625    600.533447265625   0.994408130645752
#
#                   Column5             Column6             Column7  \
# 1                tailbase            tailbase            tailbase
# ...

# %%
# "join" rows 1 and 2 (ex: nose x, nose y, nose likelihood, ...)
#df_video_raw.iloc[0] + ' ' + df_video_raw.iloc[1]
df_video_raw.iloc[0] + ' ' + '(' + df_video_raw.iloc[1] + ')'
df_video_raw.iloc[0] = df_video_raw.iloc[0] + ' ' + '(' + df_video_raw.iloc[1] + ')'

# %%
# remove row 'x, y, likelihood, x, y, likelihood
df_video_raw.drop(index=2)
# Out:
#                   Column2             Column3             Column4  \
# 1                nose (x)            nose (y)   nose (likelihood)
# 3      156.81517028808594  227.42062377929688  0.9999908208847046
# 4      157.75209045410156  233.62486267089844  0.9999220371246338
# 5       158.3218994140625   238.5648651123047  0.9999498128890991
# 6       158.3218994140625  242.77053833007812  0.9999330043792725
# ...                   ...                 ...                 ...
# 18862  277.65142822265625   601.4768676757812  0.9998972415924072
# 18863   272.4924011230469   601.4768676757812  0.9996892213821411
# 18864  264.37518310546875       601.912109375  0.9981042146682739
# 18865       259.603515625   601.4768676757812  0.9998396635055542
# 18866  253.30963134765625    600.533447265625   0.994408130645752
#
#                   Column5             Column6                Column7  \
# 1            tailbase (x)        tailbase (y)  tailbase (likelihood)
# ...

# %%
#rename the columns with index 1 and remove indexes 1 and 2
df_video_raw.columns = df_video_raw.iloc[0]

# %%
# showing the dataframe
df_video_raw
# Out:
# 1                nose (x)            nose (y)   nose (likelihood)  \
# 1                nose (x)            nose (y)   nose (likelihood)
# 2                       x                   y          likelihood
# 3      156.81517028808594  227.42062377929688  0.9999908208847046
# 4      157.75209045410156  233.62486267089844  0.9999220371246338
# 5       158.3218994140625   238.5648651123047  0.9999498128890991
# ...                   ...                 ...                 ...
# 18862  277.65142822265625   601.4768676757812  0.9998972415924072
# 18863   272.4924011230469   601.4768676757812  0.9996892213821411
# 18864  264.37518310546875       601.912109375  0.9981042146682739
# 18865       259.603515625   601.4768676757812  0.9998396635055542
# 18866  253.30963134765625    600.533447265625   0.994408130645752
#
# 1            tailbase (x)        tailbase (y)  tailbase (likelihood)  \
# 1            tailbase (x)        tailbase (y)  tailbase (likelihood)
# ...

# %%
# remove index1
df_video_raw = df_video_raw.drop(index=1)

# %%
# remove index 2
df_video_raw = df_video_raw.drop(index=2)

# %%
# showing dataframe
df_video_raw
# Out:
# 1                nose (x)            nose (y)   nose (likelihood)  \
# 3      156.81517028808594  227.42062377929688  0.9999908208847046
# 4      157.75209045410156  233.62486267089844  0.9999220371246338
# 5       158.3218994140625   238.5648651123047  0.9999498128890991
# 6       158.3218994140625  242.77053833007812  0.9999330043792725
# 7       158.3218994140625   249.2820587158203  0.9998996257781982
# ...                   ...                 ...                 ...
# 18862  277.65142822265625   601.4768676757812  0.9998972415924072
# 18863   272.4924011230469   601.4768676757812  0.9996892213821411
# 18864  264.37518310546875       601.912109375  0.9981042146682739
# 18865       259.603515625   601.4768676757812  0.9998396635055542
# 18866  253.30963134765625    600.533447265625   0.994408130645752
#
# 1            tailbase (x)        tailbase (y) tailbase (likelihood)  \
# 3       207.9359588623047  111.24932861328125    0.9999423027038574
# ...

# %%
#display the likelihood values
df_video_raw['nose (likelihood)']
# Out:
# 3        0.9999908208847046
# 4        0.9999220371246338
# 5        0.9999498128890991
# 6        0.9999330043792725
# 7        0.9998996257781982
#                 ...
# 18862    0.9998972415924072
# 18863    0.9996892213821411
# 18864    0.9981042146682739
# 18865    0.9998396635055542
# 18866     0.994408130645752
# Name: nose (likelihood), Length: 18864, dtype: object

# %% [markdown]
# # Visualizing the Errors

# %%
#do a line plot of the likelihoods
import numpy as np
import matplotlib.pyplot as plt
#use .astype() to convert from object to float
bodypart = 'nose (likelihood)'
df_video_raw[bodypart].astype(float, errors='raise').plot(kind='line',
                                                                     xlabel='Frame', 
                                                                     ylabel='Likelihood (0-1)',
                                                                     title='Likelihood of the' + ' ' + bodypart + ' ' + 'mark being correct across time',
                                                                     figsize=(20,4))
plt.show()

# %%
# likelihood kde
# plot the histogram
import numpy as np
import matplotlib.pyplot as plt

# only two visible bins
df_video_raw['tailbase (likelihood)'].astype(float, errors='raise').plot(kind='kde', xlim=(0, 1))

# plot everything in the same figure
plt.show()

# %%
# select only columns relative to likelihood
bodyparts = [col for col in df_video_raw.columns if 'likelihood' in col]
print(bodyparts)

# print (df_video_raw.columns.str.contains('likelihood'))
# print(df_video_raw.iloc[:, np.where(df_video_raw.columns.str.contains('likelihood'))[0]])
# np.where(df_video_raw.columns.str.contains('likelihood'))[0]
# Out:
# ['nose (likelihood)', 'tailbase (likelihood)', 'tailtip (likelihood)', 'left_frontlimb_digitaltip (likelihood)', 'right_frontlimb_digitaltip (likelihood)', 'left_hindlimb_digitaltip (likelihood)', 'right_hindlimb_digitaltip (likelihood)', 'left_frontlimb_heel (likelihood)', 'right_frontlimb_heel (likelihood)', 'left_hindlimb_heel (likelihood)', 'right_hindlimb_heel (likelihood)']

# %%
# ploting the likelihoods of every bodypart in a single plot (for a specific video)
for bodypart in bodyparts:
    df_video_raw[bodypart].astype(float, errors='raise').plot(kind='line',
                                                                     xlabel='Frame', 
                                                                     ylabel='Likelihood (0-1)',
                                                                     title='Likelihood of the' + ' ' + bodypart + ' ' + 'mark being correct across time',
                                                                     figsize=(20,4))

# %%
# create a new dataframe containing only the likelihoods
df_likelihoods = df_video_raw[bodyparts]
# showing the new dataframe
df_likelihoods
# Out:
# 1       nose (likelihood) tailbase (likelihood) tailtip (likelihood)  \
# 3      0.9999908208847046    0.9999423027038574    0.999987006187439
# 4      0.9999220371246338    0.9999904632568359   0.9999904632568359
# 5      0.9999498128890991    0.9999946355819702   0.9999929666519165
# 6      0.9999330043792725    0.9999587535858154    0.999991774559021
# 7      0.9998996257781982    0.9999895095825195   0.9999947547912598
# ...                   ...                   ...                  ...
# 18862  0.9998972415924072    0.9999620914459229    0.999964714050293
# 18863  0.9996892213821411    0.9999474287033081   0.9999204874038696
# 18864  0.9981042146682739    0.9999508857727051   0.9999700784683228
# 18865  0.9998396635055542    0.9999673366546631   0.9978259205818176
# 18866   0.994408130645752    0.9999876022338867  0.03695423901081085
#
# 1     left_frontlimb_digitaltip (likelihood)  \
# 3                         0.9283623695373535
# ...

# %%
# subplot all the likelihoods
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df_likelihoods.astype(float, errors='raise').plot(subplots=True, xlabel='Frame', 
                                                                     ylabel='Likelihood (0-1)',
                                                                     title='Likelihood of the bodypart marks being correct across time',
                                                                     figsize=(20,30))

plt.show()

# %%
df_video_raw
# Out:
# 1                nose (x)            nose (y)   nose (likelihood)  \
# 3      156.81517028808594  227.42062377929688  0.9999908208847046
# 4      157.75209045410156  233.62486267089844  0.9999220371246338
# 5       158.3218994140625   238.5648651123047  0.9999498128890991
# 6       158.3218994140625  242.77053833007812  0.9999330043792725
# 7       158.3218994140625   249.2820587158203  0.9998996257781982
# ...                   ...                 ...                 ...
# 18862  277.65142822265625   601.4768676757812  0.9998972415924072
# 18863   272.4924011230469   601.4768676757812  0.9996892213821411
# 18864  264.37518310546875       601.912109375  0.9981042146682739
# 18865       259.603515625   601.4768676757812  0.9998396635055542
# 18866  253.30963134765625    600.533447265625   0.994408130645752
#
# 1            tailbase (x)        tailbase (y) tailbase (likelihood)  \
# 3       207.9359588623047  111.24932861328125    0.9999423027038574
# ...

# %% [markdown]
# # Creating an image where the likelihoods will be plotted

# %%
from PIL import Image

# %%
# create a blank image with the size of the frames
# image_likelihoods = Image.new('RGB', (896, 716), (255, 255, 255))
image_likelihoods = Image.new('RGB', (896, 716))

# %%
# save the image
image_likelihoods.save("C:\\Users\\user\\Desktop\\image_likelihoods.png", "PNG")

# %%
image_likelihoods
# Out:
# <PIL.Image.Image image mode=RGB size=896x716 at 0x17DAB5C0E50>

# %%
df_video_raw['# frame'] = np.arange(len(df_video_raw))+1
df_video_raw
# Out:
# 1                nose (x)            nose (y)   nose (likelihood)  \
# 3      156.81517028808594  227.42062377929688  0.9999908208847046
# 4      157.75209045410156  233.62486267089844  0.9999220371246338
# 5       158.3218994140625   238.5648651123047  0.9999498128890991
# 6       158.3218994140625  242.77053833007812  0.9999330043792725
# 7       158.3218994140625   249.2820587158203  0.9998996257781982
# ...                   ...                 ...                 ...
# 18862  277.65142822265625   601.4768676757812  0.9998972415924072
# 18863   272.4924011230469   601.4768676757812  0.9996892213821411
# 18864  264.37518310546875       601.912109375  0.9981042146682739
# 18865       259.603515625   601.4768676757812  0.9998396635055542
# 18866  253.30963134765625    600.533447265625   0.994408130645752
#
# 1            tailbase (x)        tailbase (y) tailbase (likelihood)  \
# 3       207.9359588623047  111.24932861328125    0.9999423027038574
# ...

# %%
df_video_raw = df_video_raw.set_index('# frame')
df_video_raw
# Out:
# 1                  nose (x)            nose (y)   nose (likelihood)  \
# # frame
# 1        156.81517028808594  227.42062377929688  0.9999908208847046
# 2        157.75209045410156  233.62486267089844  0.9999220371246338
# 3         158.3218994140625   238.5648651123047  0.9999498128890991
# 4         158.3218994140625  242.77053833007812  0.9999330043792725
# 5         158.3218994140625   249.2820587158203  0.9998996257781982
# ...                     ...                 ...                 ...
# 18860    277.65142822265625   601.4768676757812  0.9998972415924072
# 18861     272.4924011230469   601.4768676757812  0.9996892213821411
# 18862    264.37518310546875       601.912109375  0.9981042146682739
# 18863         259.603515625   601.4768676757812  0.9998396635055542
# 18864    253.30963134765625    600.533447265625   0.994408130645752
#
# 1              tailbase (x)        tailbase (y) tailbase (likelihood)  \
# # frame
# ...

# %%
# remove decimal cases from the coordinates
coordinates = [col for col in df_video_raw.columns if '(x)' in col] + [col for col in df_video_raw.columns if '(y)' in col]
coordinates
# Out:
# ['nose (x)',
#  'tailbase (x)',
#  'tailtip (x)',
#  'left_frontlimb_digitaltip (x)',
#  'right_frontlimb_digitaltip (x)',
#  'left_hindlimb_digitaltip (x)',
#  'right_hindlimb_digitaltip (x)',
#  'left_frontlimb_heel (x)',
#  'right_frontlimb_heel (x)',
#  'left_hindlimb_heel (x)',
#  'right_hindlimb_heel (x)',
#  'nose (y)',
#  'tailbase (y)',
#  'tailtip (y)',
#  'left_frontlimb_digitaltip (y)',
#  'right_frontlimb_digitaltip (y)',
#  'left_hindlimb_digitaltip (y)',
#  'right_hindlimb_digitaltip (y)',
#  'left_frontlimb_heel (y)',
#  'right_frontlimb_heel (y)',
#  'left_hindlimb_heel (y)',
#  'right_hindlimb_heel (y)']

# %%
df_video_raw[coordinates]
# Out:
# 1                  nose (x)        tailbase (x)         tailtip (x)  \
# # frame
# 1        156.81517028808594   207.9359588623047      323.7373046875
# 2        157.75209045410156   207.9359588623047      323.7373046875
# 3         158.3218994140625   207.9359588623047      323.7373046875
# 4         158.3218994140625  206.18299865722656   321.2566223144531
# 5         158.3218994140625   205.6700897216797  320.52764892578125
# ...                     ...                 ...                 ...
# 18860    277.65142822265625  406.76177978515625  493.57696533203125
# 18861     272.4924011230469   398.6102600097656   491.8436279296875
# 18862    264.37518310546875   391.4034729003906   491.8436279296875
# 18863         259.603515625   383.4566955566406   483.9762268066406
# 18864    253.30963134765625  373.77825927734375   303.7206726074219
#
# 1       left_frontlimb_digitaltip (x) right_frontlimb_digitaltip (x)  \
# # frame
# ...

# %%
df_video_raw['nose (x)'].astype(float)
# Out:
# # frame
# 1        156.815170
# 2        157.752090
# 3        158.321899
# 4        158.321899
# 5        158.321899
#             ...
# 18860    277.651428
# 18861    272.492401
# 18862    264.375183
# 18863    259.603516
# 18864    253.309631
# Name: nose (x), Length: 18864, dtype: float64

# %%
df_video_raw = df_video_raw.astype(float)

# %%
# all columns have float values
for col in df_video_raw.columns:
    print(df_video_raw[col].dtype)
# Out:
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64

# %%
# now I want to turn the coordinates into integers
for col in df_video_raw[coordinates]:
    print(col)
# Out:
# nose (x)
# tailbase (x)
# tailtip (x)
# left_frontlimb_digitaltip (x)
# right_frontlimb_digitaltip (x)
# left_hindlimb_digitaltip (x)
# right_hindlimb_digitaltip (x)
# left_frontlimb_heel (x)
# right_frontlimb_heel (x)
# left_hindlimb_heel (x)
# right_hindlimb_heel (x)
# nose (y)
# tailbase (y)
# tailtip (y)
# left_frontlimb_digitaltip (y)
# right_frontlimb_digitaltip (y)
# left_hindlimb_digitaltip (y)
# right_hindlimb_digitaltip (y)
# left_frontlimb_heel (y)
# right_frontlimb_heel (y)
# left_hindlimb_heel (y)
# right_hindlimb_heel (y)

# %%
for col in coordinates:    
    df_video_raw[col] = df_video_raw[col].round(0).apply(int)

# %%
# now all data types are like desired (int coordinates and float likelihoods)
for col in df_video_raw.columns:
    print(df_video_raw[col].dtype)
# Out:
# int64
# int64
# float64
# int64
# int64
# float64
# int64
# int64
# float64
# int64
# int64
# float64
# int64
# int64
# float64
# int64
# int64
# float64
# int64
# int64
# float64
# int64
# int64
# float64
# int64
# int64
# float64
# int64
# int64
# float64
# int64
# int64
# float64

# %%
# showing the dataframe
df_video_raw
# Out:
# 1        nose (x)  nose (y)  nose (likelihood)  tailbase (x)  tailbase (y)  \
# # frame
# 1             157       227           0.999991           208           111
# 2             158       234           0.999922           208           112
# 3             158       239           0.999950           208           116
# 4             158       243           0.999933           206           120
# 5             158       249           0.999900           206           125
# ...           ...       ...                ...           ...           ...
# 18860         278       601           0.999897           407           601
# 18861         272       601           0.999689           399           601
# 18862         264       602           0.998104           391           601
# 18863         260       601           0.999840           383           601
# 18864         253       601           0.994408           374           600
#
# ...

# %%
df_video_raw.sort_values(by='nose (x)')
# Out:
# 1        nose (x)  nose (y)  nose (likelihood)  tailbase (x)  tailbase (y)  \
# # frame
# 17413         139       207           0.999955           167           335
# 17414         139       208           0.999975           167           334
# 17412         139       205           0.999900           166           335
# 17411         139       204           0.999800           166           336
# 17410         139       204           0.999749           166           336
# ...           ...       ...                ...           ...           ...
# 15252         768       461           0.996293           673           371
# 15256         768       462           0.998525           672           371
# 15253         769       461           0.994450           672           371
# 15254         769       461           0.995892           672           371
# 15255         769       461           0.998420           672           371
#
# ...

# %% [markdown]
# Add color to pixels

# %%
import cv2
import numpy as np
import time
import random

# %%
# test1
img_path = r"C:\Users\user\Desktop\image_likelihoods.png"
 
img = cv2.imread(img_path)

for height in df_video_raw['tailbase (y)']:
    img[height][850] = np.array([255,255,255])
cv2.imshow("Image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# test2
img_path = r"C:\Users\user\Desktop\image_likelihoods.png"
 
img = cv2.imread(img_path)

for width in df_video_raw['tailbase (x)']:
    img[100][width] = np.array([255,255,255])
cv2.imshow("Image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# plots the (x,y) location of the tailbase for the hole video
img_path = r"C:\Users\user\Desktop\image_likelihoods.png"
 
img = cv2.imread(img_path)

for height, width in zip(df_video_raw['tailbase (y)'], df_video_raw['tailbase (x)']):
    img[height][width] = np.array([255,255,255])
cv2.imshow("Image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# create a new dataframe only containing the tailbase info
df_tailbase = df_video_raw[['tailbase (x)', 'tailbase (y)', 'tailbase (likelihood)']]
df_tailbase
# Out:
# 1        tailbase (x)  tailbase (y)  tailbase (likelihood)
# # frame
# 1                 208           111               0.999942
# 2                 208           112               0.999990
# 3                 208           116               0.999995
# 4                 206           120               0.999959
# 5                 206           125               0.999990
# ...               ...           ...                    ...
# 18860             407           601               0.999962
# 18861             399           601               0.999947
# 18862             391           601               0.999951
# 18863             383           601               0.999967
# 18864             374           600               0.999988
#
# [18864 rows x 3 columns]

# %%
# sort a new dataframe by the likelihood so that i can drop the rows where likelihood is higher than a certain treshold
# not necessary...
df_tailbase_sorted = df_tailbase.sort_values(by='tailbase (likelihood)')

# %%
df_tailbase_worst_frames = df_tailbase_sorted.loc[(df_tailbase_sorted["tailbase (likelihood)"] < 0.99)]

# %%
# plots the (x,y) location of the tailbase for the hole video
img_path = r"C:\Users\user\Desktop\image_likelihoods.png"
 
img = cv2.imread(img_path)

for height, width in zip(df_video_raw['tailbase (y)'], df_video_raw['tailbase (x)']):
    img[height][width] = np.array([255,0,255])
    
for height, width in zip(df_tailbase_worst_frames['tailbase (y)'], df_tailbase_worst_frames['tailbase (x)']):
    img[height][width] = np.array([0,255,0])
    
cv2.imshow("Image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# plots the (x,y) location of the tailbase for the hole video
# now the goal is to atribute a color scheme related to th likelihood
img_path = r"C:\Users\user\Desktop\image_likelihoods.png"
 
img = cv2.imread(img_path)

for height, width in zip(df_video_raw['nose (y)'], df_video_raw['nose (x)']):
    img[height][width] = np.array([255,255,255])
cv2.imshow("Image", img)

n_white_pix = np.sum(img == 255)
if n_white_pix > len(df_video_raw):
    print('The number of white px in this image is', n_white_pix)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# The number of white px in this image is 27249

# %% [markdown]
# It makes more sense to implement an analogous aproach to the limbs, since they are more error prone

# %%
#so...repeating the process
# create a new dataframe only containing the tailbase info
df_rhlh = df_video_raw[['right_hindlimb_heel (x)', 'right_hindlimb_heel (y)', 'right_hindlimb_heel (likelihood)']]
df_rhlh
# Out:
# 1        right_hindlimb_heel (x)  right_hindlimb_heel (y)  \
# # frame
# 1                            220                      119
# 2                            220                      121
# 3                            220                      126
# 4                            214                      130
# 5                            209                      143
# ...                          ...                      ...
# 18860                        386                      621
# 18861                        381                      621
# 18862                        370                      621
# 18863                        352                      621
# 18864                        332                      621
#
# 1        right_hindlimb_heel (likelihood)
# # frame
# 1                                0.998618
# 2                                0.999145
# 3                                0.998676
# 4                                0.999690
# ...

# %%
df_rhlh_worst = df_rhlh.loc[(df_rhlh["right_hindlimb_heel (likelihood)"] < 0.99)]
df_rhlh_worst
# Out:
# 1        right_hindlimb_heel (x)  right_hindlimb_heel (y)  \
# # frame
# 13                           194                      177
# 14                           194                      180
# 23                           178                      255
# 25                           178                      264
# 26                           180                      270
# ...                          ...                      ...
# 18688                        661                      577
# 18689                        659                      582
# 18709                        654                      581
# 18710                        652                      581
# 18711                        652                      582
#
# 1        right_hindlimb_heel (likelihood)
# # frame
# 13                               0.920952
# 14                               0.915857
# 23                               0.981615
# 25                               0.988527
# ...

# %%
# heat map of the regions where the mice has been AND are likelihood < 0.99
from scipy.ndimage import gaussian_filter
test=np.zeros((716,896))
for index,row in df_rhlh_worst.iterrows():
    test[int(row['right_hindlimb_heel (y)']),int(row['right_hindlimb_heel (x)'])] += 1
    
plt.imshow(gaussian_filter(test,sigma=10))
np.sum(test)
# Out:
# 1667.0

# %%
# heat map of the regions where the mice has been
test_1=np.zeros((716,896))
for index,row in df_rhlh.iterrows():
    test_1[int(row['right_hindlimb_heel (y)']),int(row['right_hindlimb_heel (x)'])] += 1
    
plt.imshow(gaussian_filter(test_1,sigma=10))
np.sum(test_1)
# Out:
# 18864.0

# %%
plt.imshow(gaussian_filter(test,sigma=30)/gaussian_filter(test_1,sigma=30))
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_26092\1604024235.py:1: RuntimeWarning: invalid value encountered in true_divide
#   plt.imshow(gaussian_filter(test,sigma=30)/gaussian_filter(test_1,sigma=30))

# %%
# not complete!!

# tries to iterate over an image and count pixels from specific colors 
# ....in order to obtain the ratio between good and bad labeled frames
img_path = r"C:\Users\user\Desktop\image_likelihoods.png"
 
img = cv2.imread(img_path)

num_violet_pix = 0
for height, width in zip(df_video_raw['right_hindlimb_heel (y)'], df_video_raw['right_hindlimb_heel (x)']):
    img[height][width] = np.array([255,0,255])
#    img[height][width] = np.array(100)
    num_violet_pix +=1
    
num_green_pix = 0
for height, width in zip(df_rhlh_worst['right_hindlimb_heel (y)'], df_rhlh_worst['right_hindlimb_heel (x)']):
    img[height][width] = np.array([0,255,0])
#    img[height][width] = np.array(200)
    num_green_pix +=1

num_violet_pix = num_violet_pix - num_green_pix
print('The number of violet pixels is', num_violet_pix)
print('The number of green pixels is', num_green_pix)

if num_violet_pix == np.sum(img == [255,0,255]) and num_green_pix == np.sum(img == [0,255,0]):
    print('The pixel counting by np.sum is correct')
else:
    print('The pixel counting by np.sum is INCORRECT!')

cv2.imshow("Image", img)

n_black_pix = np.sum(img == 0)
print(n_black_pix)
'''
n_dark_gray_pix = np.sum(img == 100)
print(n_dark_gray_pix)
n_gray_pix = np.sum(img == 200)
print(n_gray_pix)
'''

def get_num_pixels(filepath):
    width, height = Image.open(filepath).size
    return width*height

print('This image has ' + str(get_num_pixels(img_path)) + ' pixels')

# save a new image containing the violet and green pixels
cv2.imwrite(r'C:\\Users\\user\\Desktop\\Test_violet_green.png', img) 

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# The number of violet pixels is 17197
# The number of green pixels is 1667
# The pixel counting by np.sum is INCORRECT!
# 1916906
# This image has 641536 pixels

# %%
# attempt to do the same thing the previous cell does, but with pillow library
from PIL import Image
im = Image.open(r"C:\\Users\\user\\Desktop\\image_likelihoods.png")
pixels = im.load() # create the pixel map

'''
for i in range(img.size[0]): # for every pixel:
    for j in range(img.size[1]):
        if pixels[i,j] != (255, 0, 0):
            # change to black if not red
            pixels[i,j] = (0, 0 ,0)
'''

violet_pix = 0
for i in range(img.size[0]): # for every pixel:
    for j in range(img.size[1]):
        pixels[i, j] = (255, 0 ,255)
        violet_pix +=1
    
green_pix = 0
for i in range(img.size[0]): # for every pixel:
    for j in range(img.size[1]):
        pixels[i, j] = (0, 255 ,0)    
        green_pix +=1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [114], in <cell line: 15>()
#       6 '''
#       7 for i in range(img.size[0]): # for every pixel:
#       8     for j in range(img.size[1]):
#    (...)
#      11             pixels[i,j] = (0, 0 ,0)
#      12 '''
#      14 violet_pix = 0
# ---> 15 for i in range(img.size[0]): # for every pixel:
#      16     for j in range(img.size[1]):
#      17         pixels[i, j] = (255, 0 ,255)
#
# TypeError: 'int' object is not subscriptable

# %%
# not complete!!
from PIL import Image

im = Image.open(r"C:\\Users\\user\\Desktop\\image_likelihoods.png")
px = im.load()

height = img.shape[0]
print(height)
width = img.shape[1]
print(width)

# iterate through each pixel in the image and keep a count per unique color
numblack = 0
numviolet = 0 
numgreen = 0

for x in range(width):
    for y in range(height):
        im.getpixel((x, y))

        if im.getpixel((x, y))==(0,0,0):
            numblack += 1
        elif im.getpixel((x,y))==(255,0,255):
            numviolet +=1
        elif im.getpixel((x,y))==(0,255,0):
            numgreen += 1
            
print('Number of black pixels is : ', numblack)
print('Number of violet and green pixels is: ' + str(numviolet) + ' and ' + str(numgreen) + ', respectively')
if numgreen!=0:
    ratio_good_bad = numviolet/numgreen
else:
    print('There are no green pixels')
    
print('The ratio of "correctly" labeled to "badly" labeled frames is: ', ratio_good_bad)
# Out:
# 716
# 896
# Number of black pixels is :  641536
# Number of violet and green pixels is: 0 and 0, respectively
# There are no green pixels
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [115], in <cell line: 35>()
#      32 else:
#      33     print('There are no green pixels')
# ---> 35 print('The ratio of "correctly" labeled to "badly" labeled frames is: ', ratio_good_bad)
#
# NameError: name 'ratio_good_bad' is not defined

# %%
# define a net over the image so to devide the image in multiple squared for error "quantification"
# asign each square with the ratio between fr with 
        # ...acceptable likelihood and unacceptable likelihood (violet/green pixels)
# do not consider squares without any point(where the mice hasn't been)
# define the centre square from the net and plot the ratio by distance to the centre 
    # (this should give us some information on the dependency of the likelihood to the location of the mice in the OF)

# %%
# Image path, number of rows 
# and number of columns 
# should be provided as an arguments
import cv2
import sys
import os

'''
if not os.path.exists('patches'):
    os.makedirs('patches')
'''

# Number of Rows
# nRows = int(sys.argv[2])
nRows = 10
# Number of columns
# mCols = int(sys.argv[3])
mCols = 8

img_path = r"C:\Users\user\Desktop\image_likelihoods.png"
img = cv2.imread(img_path)

# Reading image
########img = cv2.imread(sys.argv[1])
#print img

#cv2.imshow('image',img)

# Dimensions of the image
sizeX = img.shape[1]
sizeY = img.shape[0]

print(img.shape)


# sizeY/nRows needs to be an integer
count=0
for i in range(0,nRows):
    for j in range(0, mCols):
        roi = img[i*int(sizeY/nRows):i*int(sizeY/nRows) + int(sizeY/nRows) ,j*int(sizeX/mCols):j*int(sizeX/mCols) + int(sizeX/mCols)]
        count+=1
        # cv2.imshow('rois'+str(i)+str(j), roi)
        # cv2.imwrite(r'C:/Users/user/Desktop/patch_'+str(i)+str(j)+".jpg", roi)

# print the number of regions of interest        
print(count)
cv2.waitKey()

# n_color_pix = n_violet_pix + n_green_pix
